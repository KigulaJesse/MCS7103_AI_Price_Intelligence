# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re

# %%
BASE_URL = "https://www.beforward.jp/stocklist?page={}"
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:109.0)"
}

USD_TO_UGX = 3600

# %%
def clean_price(value):
    if pd.isna(value) or value is None:
        return None

    # Convert list to string if needed
    if isinstance(value, list):
        if len(value) == 0:
            return None
        value = value[0]

    # Convert to string
    s = str(value)

    # Remove dollar signs, commas, and whitespace
    s = s.replace("$", "").replace(",", "").strip()

    # Extract digits only
    digits = re.sub(r"\D", "", s)

    return int(digits) if digits else None

# %%
def extract_year(title):
    """Find 4-digit year in title like '2025 SUZUKI EVERY'."""
    m = re.search(r"(19|20)\d{2}", title)
    return int(m.group()) if m else None

# %%
def parse_row(row):
    cols = row.find_all("td")
    if len(cols) < 3:
        return None
    
    # --- COLUMN 1: Photo + URL + Ref ---
    first = cols[0]

    # URL
    link_tag = first.find("a", class_="vehicle-url-link")
    url = link_tag["href"] if link_tag else None

    # Ref Number
    ref_tag = first.select_one("p.veh-stock-no span")
    ref_no = ref_tag.text.strip().replace("Ref No. ", "") if ref_tag else None

    # --- COLUMN 2: Description Column ---
    second = cols[1]

    # Title (includes year + make + model)
    title_tag = second.select_one("p.make-model a")
    title = title_tag.text.strip() if title_tag else None

    # Specs
    mileage = second.select_one("td.mileage p.val")
    mileage = mileage.text.strip() if mileage else None

    year_val = second.select_one("td.year p.val")
    year = year_val.text.strip() if year_val else extract_year(title or "")

    engine_cc = second.select_one("td.engine p.val")
    engine_cc = engine_cc.text.strip() if engine_cc else None

    transmission = second.select_one("td.trans p.val")
    transmission = transmission.text.strip() if transmission else None

    location = second.select_one("td.location span")
    location = location.text.strip() if location else None

    # Extra specs (Fuel, Seats)
    fuel = seats = None
    detailed_rows = second.select("table.table-detailed-spec td")

    for i, cell in enumerate(detailed_rows):
        label = cell.text.strip().lower()
        if label == "fuel":
            fuel = detailed_rows[i+1].text.strip()
        if label == "seats":
            seats = detailed_rows[i+1].text.strip()

    # --- COLUMN 3: Price Column ---
    third = cols[2]

    price_td = row.select_one("td.price-col")
    if price_td:
        price_el = price_td.select_one("p.vehicle-price span.price")
        total_price_el = price_td.select_one("p.total-price span:not(.currency-label)")
        if price_el:
            raw_price = price_el.get_text(strip=True)
            price_usd = clean_price(raw_price)
            raw_total_price = total_price_el.get_text(strip=True)
            total_price_usd = clean_price(raw_total_price)
        else:
            return
    else: 
        return

    price_ugx = price_usd * USD_TO_UGX if price_usd else None
    total_price_ugx = total_price_usd * USD_TO_UGX if total_price_usd else None

    make = model = None
    if title:
        parts = title.split()
        if len(parts) >= 2:
            make = parts[1]
        if len(parts) >= 3:
            model = parts[2]

    return {
        "ref_no": ref_no,
        "title": title,
        "make": make,
        "model": model,
        "year": year,
        "mileage": mileage,
        "engine_cc": engine_cc,
        "transmission": transmission,
        "fuel": fuel,
        "seats": seats,
        "location": location,
        "price_usd": price_usd,
        "total_price_usd": total_price_usd,
        "price_ugx": price_ugx,
        "total_price_ugx": total_price_ugx,
        "url": url
    }

# %%
#testing getting my element, it was giving me a hard time.
from bs4 import BeautifulSoup

html = """<p class="vehicle-price"><span class="price">$9,800</span></p>"""

soup = BeautifulSoup(html, "html.parser")
el = soup.select_one("p.vehicle-price span.price")
print(el.get_text(strip=True))
# Out:
# $9,800

# %%
def scrape_beforward(max_pages=20, delay=1.5):
    cars = []

    for page in range(1, max_pages + 1):
        print(f"Scraping page {page} -> {BASE_URL.format(page)}")
        resp = requests.get(BASE_URL.format(page), headers=HEADERS)

        if resp.status_code != 200:
            print("Failed:", resp.status_code)
            break

        soup = BeautifulSoup(resp.text, "html.parser")
        rows = soup.select("tr.stocklist-row")

        if not rows:
            print("No more rows found. Stopping.")
            break

        print(f"Found {len(rows)} cars on page {page}")

        for row in rows:
            """Testing Fetching prices from HTML"""
            # price_td = row.select_one("td.price-col")
            # if price_td:
            #     price_el = price_td.select_one("p.vehicle-price span.price")
            #     total_price_el = price_td.select_one("p.total-price span:not(.currency-label)")
            #     if price_el:
            #         raw_price = price_el.get_text(strip=True)
            #         price_usd = clean_price(raw_price)
            #         raw_total_price = total_price_el.get_text(strip=True)
            #         total_price_usd = clean_price(raw_total_price)
            #     else:
            #         continue
            # else: 
            #     continue
            # print("Price, Total price:", price_usd,total_price_usd)
            car = parse_row(row)
            if car:
                cars.append(car)

        time.sleep(delay)

    return pd.DataFrame(cars)

# %%
df_bef = scrape_beforward(max_pages=100)
df_bef.to_csv("raw_data/beforward_raw.csv", index=False)

df_bef.head()
# Out:
# Scraping page 1 -> https://www.beforward.jp/stocklist?page=1
# Found 28 cars on page 1
# Scraping page 2 -> https://www.beforward.jp/stocklist?page=2
# Found 28 cars on page 2
# Scraping page 3 -> https://www.beforward.jp/stocklist?page=3
# Found 28 cars on page 3
# Scraping page 4 -> https://www.beforward.jp/stocklist?page=4
# Found 28 cars on page 4
# Scraping page 5 -> https://www.beforward.jp/stocklist?page=5
# Found 28 cars on page 5
# Scraping page 6 -> https://www.beforward.jp/stocklist?page=6
# Found 28 cars on page 6
# Scraping page 7 -> https://www.beforward.jp/stocklist?page=7
# Found 28 cars on page 7
# Scraping page 8 -> https://www.beforward.jp/stocklist?page=8
# Found 28 cars on page 8
# Scraping page 9 -> https://www.beforward.jp/stocklist?page=9
# Found 28 cars on page 9
# Scraping page 10 -> https://www.beforward.jp/stocklist?page=10
# Found 28 cars on page 10
# Scraping page 11 -> https://www.beforward.jp/stocklist?page=11
# Found 28 cars on page 11
# Scraping page 12 -> https://www.beforward.jp/stocklist?page=12
# Found 28 cars on page 12
# Scraping page 13 -> https://www.beforward.jp/stocklist?page=13
# Found 28 cars on page 13
# Scraping page 14 -> https://www.beforward.jp/stocklist?page=14
# Found 28 cars on page 14
# Scraping page 15 -> https://www.beforward.jp/stocklist?page=15
# Found 28 cars on page 15
# Scraping page 16 -> https://www.beforward.jp/stocklist?page=16
# Found 28 cars on page 16
# Scraping page 17 -> https://www.beforward.jp/stocklist?page=17
# Found 28 cars on page 17
# Scraping page 18 -> https://www.beforward.jp/stocklist?page=18
# Found 28 cars on page 18
# Scraping page 19 -> https://www.beforward.jp/stocklist?page=19
# Found 28 cars on page 19
# Scraping page 20 -> https://www.beforward.jp/stocklist?page=20
# Found 28 cars on page 20
# Scraping page 21 -> https://www.beforward.jp/stocklist?page=21
# Found 28 cars on page 21
# Scraping page 22 -> https://www.beforward.jp/stocklist?page=22
# Found 28 cars on page 22
# Scraping page 23 -> https://www.beforward.jp/stocklist?page=23
# Found 28 cars on page 23
# Scraping page 24 -> https://www.beforward.jp/stocklist?page=24
# Found 28 cars on page 24
# Scraping page 25 -> https://www.beforward.jp/stocklist?page=25
# Found 28 cars on page 25
# Scraping page 26 -> https://www.beforward.jp/stocklist?page=26
# Found 28 cars on page 26
# Scraping page 27 -> https://www.beforward.jp/stocklist?page=27
# Found 28 cars on page 27
# Scraping page 28 -> https://www.beforward.jp/stocklist?page=28
# Found 28 cars on page 28
# Scraping page 29 -> https://www.beforward.jp/stocklist?page=29
# Found 28 cars on page 29
# Scraping page 30 -> https://www.beforward.jp/stocklist?page=30
# Found 28 cars on page 30
# Scraping page 31 -> https://www.beforward.jp/stocklist?page=31
# Found 28 cars on page 31
# Scraping page 32 -> https://www.beforward.jp/stocklist?page=32
# Found 28 cars on page 32
# Scraping page 33 -> https://www.beforward.jp/stocklist?page=33
# Found 28 cars on page 33
# Scraping page 34 -> https://www.beforward.jp/stocklist?page=34
# Found 28 cars on page 34
# Scraping page 35 -> https://www.beforward.jp/stocklist?page=35
# Found 28 cars on page 35
# Scraping page 36 -> https://www.beforward.jp/stocklist?page=36
# Found 28 cars on page 36
# Scraping page 37 -> https://www.beforward.jp/stocklist?page=37
# Found 28 cars on page 37
# Scraping page 38 -> https://www.beforward.jp/stocklist?page=38
# Found 28 cars on page 38
# Scraping page 39 -> https://www.beforward.jp/stocklist?page=39
# Found 28 cars on page 39
# Scraping page 40 -> https://www.beforward.jp/stocklist?page=40
# Found 28 cars on page 40
# Scraping page 41 -> https://www.beforward.jp/stocklist?page=41
# Found 28 cars on page 41
# Scraping page 42 -> https://www.beforward.jp/stocklist?page=42
# Found 28 cars on page 42
# Scraping page 43 -> https://www.beforward.jp/stocklist?page=43
# Found 28 cars on page 43
# Scraping page 44 -> https://www.beforward.jp/stocklist?page=44
# Found 28 cars on page 44
# Scraping page 45 -> https://www.beforward.jp/stocklist?page=45
# Found 28 cars on page 45
# Scraping page 46 -> https://www.beforward.jp/stocklist?page=46
# Found 28 cars on page 46
# Scraping page 47 -> https://www.beforward.jp/stocklist?page=47
# Found 28 cars on page 47
# Scraping page 48 -> https://www.beforward.jp/stocklist?page=48
# Found 28 cars on page 48
# Scraping page 49 -> https://www.beforward.jp/stocklist?page=49
# Found 28 cars on page 49
# Scraping page 50 -> https://www.beforward.jp/stocklist?page=50
# Found 28 cars on page 50
# Scraping page 51 -> https://www.beforward.jp/stocklist?page=51
# Found 28 cars on page 51
# Scraping page 52 -> https://www.beforward.jp/stocklist?page=52
# Found 28 cars on page 52
# Scraping page 53 -> https://www.beforward.jp/stocklist?page=53
# Found 28 cars on page 53
# Scraping page 54 -> https://www.beforward.jp/stocklist?page=54
# Found 28 cars on page 54
# Scraping page 55 -> https://www.beforward.jp/stocklist?page=55
# Found 28 cars on page 55
# Scraping page 56 -> https://www.beforward.jp/stocklist?page=56
# Found 28 cars on page 56
# Scraping page 57 -> https://www.beforward.jp/stocklist?page=57
# Found 28 cars on page 57
# Scraping page 58 -> https://www.beforward.jp/stocklist?page=58
# Found 28 cars on page 58
# Scraping page 59 -> https://www.beforward.jp/stocklist?page=59
# Found 28 cars on page 59
# Scraping page 60 -> https://www.beforward.jp/stocklist?page=60
# Found 28 cars on page 60
# Scraping page 61 -> https://www.beforward.jp/stocklist?page=61
# Found 28 cars on page 61
# Scraping page 62 -> https://www.beforward.jp/stocklist?page=62
# Found 28 cars on page 62
# Scraping page 63 -> https://www.beforward.jp/stocklist?page=63
# Found 28 cars on page 63
# Scraping page 64 -> https://www.beforward.jp/stocklist?page=64
# Found 28 cars on page 64
# Scraping page 65 -> https://www.beforward.jp/stocklist?page=65
# Found 28 cars on page 65
# Scraping page 66 -> https://www.beforward.jp/stocklist?page=66
# Found 28 cars on page 66
# Scraping page 67 -> https://www.beforward.jp/stocklist?page=67
# Found 28 cars on page 67
# Scraping page 68 -> https://www.beforward.jp/stocklist?page=68
# Found 28 cars on page 68
# Scraping page 69 -> https://www.beforward.jp/stocklist?page=69
# Found 28 cars on page 69
# Scraping page 70 -> https://www.beforward.jp/stocklist?page=70
# Found 28 cars on page 70
# Scraping page 71 -> https://www.beforward.jp/stocklist?page=71
# Found 28 cars on page 71
# Scraping page 72 -> https://www.beforward.jp/stocklist?page=72
# Found 28 cars on page 72
# Scraping page 73 -> https://www.beforward.jp/stocklist?page=73
# Found 28 cars on page 73
# Scraping page 74 -> https://www.beforward.jp/stocklist?page=74
# Found 28 cars on page 74
# Scraping page 75 -> https://www.beforward.jp/stocklist?page=75
# Found 28 cars on page 75
# Scraping page 76 -> https://www.beforward.jp/stocklist?page=76
# Found 28 cars on page 76
# Scraping page 77 -> https://www.beforward.jp/stocklist?page=77
# Found 28 cars on page 77
# Scraping page 78 -> https://www.beforward.jp/stocklist?page=78
# Found 28 cars on page 78
# Scraping page 79 -> https://www.beforward.jp/stocklist?page=79
# Found 28 cars on page 79
# Scraping page 80 -> https://www.beforward.jp/stocklist?page=80
# Found 28 cars on page 80
# Scraping page 81 -> https://www.beforward.jp/stocklist?page=81
# Found 28 cars on page 81
# Scraping page 82 -> https://www.beforward.jp/stocklist?page=82
# Found 28 cars on page 82
# Scraping page 83 -> https://www.beforward.jp/stocklist?page=83
# Found 28 cars on page 83
# Scraping page 84 -> https://www.beforward.jp/stocklist?page=84
# Found 28 cars on page 84
# Scraping page 85 -> https://www.beforward.jp/stocklist?page=85
# Found 28 cars on page 85
# Scraping page 86 -> https://www.beforward.jp/stocklist?page=86
# Found 28 cars on page 86
# Scraping page 87 -> https://www.beforward.jp/stocklist?page=87
# Found 28 cars on page 87
# Scraping page 88 -> https://www.beforward.jp/stocklist?page=88
# Found 28 cars on page 88
# Scraping page 89 -> https://www.beforward.jp/stocklist?page=89
# Found 28 cars on page 89
# Scraping page 90 -> https://www.beforward.jp/stocklist?page=90
# Found 28 cars on page 90
# Scraping page 91 -> https://www.beforward.jp/stocklist?page=91
# Found 28 cars on page 91
# Scraping page 92 -> https://www.beforward.jp/stocklist?page=92
# Found 28 cars on page 92
# Scraping page 93 -> https://www.beforward.jp/stocklist?page=93
# Found 28 cars on page 93
# Scraping page 94 -> https://www.beforward.jp/stocklist?page=94
# Found 28 cars on page 94
# Scraping page 95 -> https://www.beforward.jp/stocklist?page=95
# Found 28 cars on page 95
# Scraping page 96 -> https://www.beforward.jp/stocklist?page=96
# Found 28 cars on page 96
# Scraping page 97 -> https://www.beforward.jp/stocklist?page=97
# Found 28 cars on page 97
# Scraping page 98 -> https://www.beforward.jp/stocklist?page=98
# Found 28 cars on page 98
# Scraping page 99 -> https://www.beforward.jp/stocklist?page=99
# Found 28 cars on page 99
# Scraping page 100 -> https://www.beforward.jp/stocklist?page=100
# Found 28 cars on page 100
#      ref_no                                              title        make  \
# 0  BY759022                              2006 HONDA ACTY TRUCK       HONDA
# 1  BY759024                             2013 MITSUBISHI CANTER  MITSUBISHI
# 2  CA462307  2014 TOYOTA HIACE VAN\n                       ...      TOYOTA
# 3  CA740447  2011 TOYOTA WISH\n                            ...      TOYOTA
# 4  CB026605  2017 HONDA FIT HYBRID\n                       ...       HONDA
#
#     model     year     mileage engine_cc transmission            fuel seats  \
# 0    ACTY  2006/12  111,250 km     650cc           MT          Petrol     2
# 1  CANTER   2013/2  312,401 km   2,990cc      Semi AT          Diesel     3
# 2   HIACE   2014/4  161,352 km   2,980cc           AT          Diesel     3
# 3    WISH   2011/9  154,001 km   1,790cc           AT          Petrol     7
# 4     FIT   2017/9  111,072 km   1,490cc           AT  Hybrid(Petrol)     5
#
#    location  price_usd  total_price_usd  price_ugx  total_price_ugx  \
# 0  Location       2370           3973.0    8532000       14302800.0
# 1  Location       3920           7747.0   14112000       27889200.0
# 2  Location       5960           8492.0   21456000       30571200.0
# 3  Location       2430           4544.0    8748000       16358400.0
# 4  Location       4790           6633.0   17244000       23878800.0
#
#                                         url
# 0   /honda/acty-truck/by759022/id/11910020/
# 1  /mitsubishi/canter/by759024/id/11910065/
# 2   /toyota/hiace-van/ca462307/id/12565207/
# 3        /toyota/wish/ca740447/id/12831915/
# 4   /honda/fit-hybrid/cb026605/id/13106276/
